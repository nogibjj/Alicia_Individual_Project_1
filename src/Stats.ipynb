# %% [markdown]
# #### Descriptive Statistics on Diabetic Patients at least 21 years old of Pima Indian heritage: Data provided by National Institute of Diabetes and Digestive and Kidney Diseases.

# %% [markdown]
# I first wanted to do a statistical analysis of the data on three predictor variables.  I investigated three different medical predictors of diabetes: Glucose, Insulin, BMI. In effort to understand if a patient had diabetes or not (1- had diabetes, 0 - does not have diabetes).

# %%
import lib
import pandas as pd

# %%
data = pd.read_csv("/workspaces/Alicia_Individual_Project_1/data/population.csv")
data[0:6]
lib.mean(data)
lib.head(data)
lib.max(data)
lib.std(data)
# Out:
# 1960         NaN
# 1961    1.379680
# 1962    1.382710
# 1963    1.521199
# 1964    1.375581
#           ...
# 2018    1.262952
# 2019    1.205299
# 2020    1.183446
# 2021    1.274807
# 2022    1.508510
# Length: 63, dtype: float64

# %% [markdown]
# I now want to visualize these descriptive statistics in three different ways. First I am going to display a countplot which shows each the counts of each data type used in this particular dataset. I want to show a bar plot that showed based the range of which specific glucose, insulin, BMI values results in a accurate diabetes diagnosis. Finally, I wanted to tabulate the data in a clean table to show how each descriptive stats compares for each of the three predictor variables.

# %%
lib.viz_population(data, jupyter=True)
lib.countries_interest(data)
# Out:
# Visualization of Population Dataset
#       Country Name Country Code                Indicator Name Indicator Code  \
# 40           China          CHN  Population growth (annual %)    SP.POP.GROW
# 77          France          FRA  Population growth (annual %)    SP.POP.GROW
# 109          India          IND  Population growth (annual %)    SP.POP.GROW
# 251  United States          USA  Population growth (annual %)    SP.POP.GROW
#
#      1960      1961      1962      1963      1964      1965  ...      2013  \
# 40    NaN -1.015528  0.820456  2.457647  2.320683  2.381368  ...  0.666073
# 77    NaN  1.090951  1.092679  1.064260  1.122661  1.119737  ...  0.516540
# 109   NaN  2.304706  2.311689  2.309079  2.301192  2.235300  ...  1.297549
# 251   NaN  1.657730  1.537997  1.439165  1.389046  1.250172  ...  0.692860
#
#          2014      2015      2016      2017      2018      2019      2020  \
# 40   0.630326  0.581456  0.573051  0.605245  0.467672  0.354741  0.238041
# ...
